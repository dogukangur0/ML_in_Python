# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('polynomial-regression.csv')

# %%
dataset
# Out:
#     araba_fiyat  araba_max_hiz
# 0            60            180
# 1            70            180
# 2            80            200
# 3           100            200
# 4           120            200
# 5           150            220
# 6           200            240
# 7           250            240
# 8           300            300
# 9           400            350
# 10          500            350
# 11          750            360
# 12         1000            365
# 13         2000            365
# 14         3000            365

# %%
X = dataset.iloc[:,:-1].values
y = dataset.iloc[:,-1].values

# %% [markdown]
# #### Training the linear regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X,y) # tüm verileri fit ederiz
# Out:
# LinearRegression()

# %% [markdown]
# #### Training the polynomial regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly,y)
# Out:
# LinearRegression()

# %%
plt.scatter(X,y,color='red')
plt.plot(X,lin_reg_2.predict(poly_reg.fit_transform(X)),color='blue')
plt.title('Araba Fiyat-Hız (Polynomial Regression)')
plt.xlabel('Araba Fiyat')
plt.ylabel('Araba Max Hız')
plt.show()

# %%
lin_reg_2.predict(poly_reg.fit_transform([[300]]))
# Out:
# array([291.83683054])
