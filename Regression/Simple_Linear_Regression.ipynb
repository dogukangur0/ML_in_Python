# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Importing the dataset

# %%
dataset = pd.read_csv('Salary_Data.csv')
X = dataset.iloc[:,:-1].values
y = dataset.iloc[:,-1].values

# %% [markdown]
# ### Splitting the dataset into training and test dataset

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# ### Training the Simple Linear Regression model on the training set

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train) # eğitim setini fit etmeliyiz. # eğitim seti = x train ve y train
# Out:
# LinearRegression()

# %% [markdown]
# ### Predicting the test set results

# %%
y_pred = regressor.predict(X_test) # features verileri alınır ve tahminler bu verilere göre yapılır.

# %% [markdown]
# ### Visualising the Training set result

# %%
plt.scatter(X_train, y_train, color='red')  # scatter -> 2d üzerinde gerçek verileri nokta şeklinde göstermek için kullanılır.
plt.plot(X_train,regressor.predict(X_train),color='blue')
plt.title('Salary and Experience (Train Set)')
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ### Visualising the Test set results

# %%
plt.scatter(X_test, y_test, color='red')  # scatter -> 2d üzerinde gerçek verileri nokta şeklinde göstermek için kullanılır.
plt.plot(X_train,regressor.predict(X_train),color='blue')
plt.title('Salary and Experience (Train Set)')
plt.xlabel('Salary')
plt.ylabel('Experience')
plt.show()
